# %% [markdown]
# ### Математика. ДЗ-1

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Задание 1

# %%
ar1 = np.matrix([[5, 10], [7,12], [11.3, 5], [25, 30]])

res = np.matrix(7 * ar1 + 2 * ar1) 
print('Matrix ar1 :\n', ar1) 

# res = ar1 + ar2 # using '+' operator print('\nResult :\n', res)
print('result :\n', res)
# Out:
# Matrix ar1 :
#  [[ 5.  10. ]
#  [ 7.  12. ]
#  [11.3  5. ]
#  [25.  30. ]]
# result :
#  [[ 45.   90. ]
#  [ 63.  108. ]
#  [101.7  45. ]
#  [225.  270. ]]

# %% [markdown]
# #### Задание 2.1

# %%
# лень решать на бумажке - слишком долго
M1 = np.array([[3, -2, 5], [7, 4, -8], [5, -3, -4]]) # Матрица (левая часть системы)
v1 = np.array([7, 3, -12]) # Вектор (правая часть системы)

# %%
np.linalg.solve(M1, v1)
# Out:
# array([1., 3., 2.])

# %%
Image(requests.get('https://github.com/stavrtin/Higher_Math/blob/main/HM_hw_1/20220423_234407.jpg').content)

# %% [markdown]
# #### Задание 2.2 и 3

# %%
Image(requests.get('https://drive.google.com/file/d/1Vujn55v0gb9j08PqQw_ycHZU3R_dysDH/view?usp=sharing').content)

# %% [markdown]
# ![Задача 2.2 и 3](https://drive.google.com/file/d/1Vujn55v0gb9j08PqQw_ycHZU3R_dysDH/view?usp=sharing)

# %% [markdown]
# #### Задание 4

# %%
x = np.linspace(0, 10, 100)
y = np.linspace(0, 10, 100)
k1 = 1
k2 = 3
plt.plot(x,np.cos(k1 * x), marker='o')
plt.plot(y,np.cos(k2 * x), marker='*')
# print(y,x)
